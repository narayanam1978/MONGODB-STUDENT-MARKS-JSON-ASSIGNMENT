# %%
# !pip install dnspython
# !pip install pymongo[srv]
# Out:
# ...
#      |████████████████████████████████| 266 kB 13.3 MB/s
# ...

# %%
import json
import pymongo
from pymongo import MongoClient
from pymongo import InsertOne

client = pymongo.MongoClient("mongodb+srv://ran:1234@cluster0.w24ly.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.d201
records = db.StudentDataJSON
records.count_documents({})
# Out:
# 200

# %%
requesting = []

with open("/content/students.json") as f:            
  for jsonObj in f:
    myDict = json.loads(jsonObj)
    requesting.append(InsertOne(myDict)) 

#reading the JSON file containing 200 documents of students

# %%
for x in records.find({},{"_id":0, "name":1}):
  print(x)
# Out:
# {'name': 'aimee Zank'}
# {'name': 'Aurelia Menendez'}
# {'name': 'Corliss Zuk'}
# {'name': 'Bao Ziglar'}
# {'name': 'Zachary Langlais'}
# {'name': 'Wilburn Spiess'}
# {'name': 'Jenette Flanders'}
# {'name': 'Salena Olmos'}
# {'name': 'Daphne Zheng'}
# {'name': 'Sanda Ryba'}
# {'name': 'Denisha Cast'}
# {'name': 'Marcus Blohm'}
# {'name': 'Quincy Danaher'}
# {'name': 'Jessika Dagenais'}
# {'name': 'Alix Sherrill'}
# {'name': 'Tambra Mercure'}
# {'name': 'Dodie Staller'}
# {'name': 'Fletcher Mcconnell'}
# {'name': 'Verdell Sowinski'}
# {'name': 'Gisela Levin'}
# {'name': 'Tressa Schwing'}
# {'name': 'Rosana Vales'}
# {'name': 'Margart Vitello'}
# {'name': 'Tamika Schildgen'}
# {'name': 'Jesusa Rickenbacker'}
# {'name': 'Rudolph Domingo'}
# {'name': 'Jonie Raby'}
# {'name': 'Edgar Sarkis'}
# {'name': 'Laureen Salomone'}
# {'name': 'Gwyneth Garling'}
# {'name': 'Kaila Deibler'}
# {'name': 'Tandra Meadows'}
# {'name': 'Gwen Honig'}
# {'name': 'Sadie Jernigan'}
# {'name': 'Carli Belvins'}
# ...

# %%
y = []
for x in records.find({},{"_id":0, "scores":1}):
  #y.append(x["scores"])
  print(x["scores"])
  #print(y)
# Out:
# [{'score': 1.463179736705023, 'type': 'exam'}, {'score': 11.78273309957772, 'type': 'quiz'}, {'score': 35.8740349954354, 'type': 'homework'}]
# [{'score': 60.06045071030959, 'type': 'exam'}, {'score': 52.79790691903873, 'type': 'quiz'}, {'score': 71.76133439165544, 'type': 'homework'}]
# [{'score': 67.03077096065002, 'type': 'exam'}, {'score': 6.301851677835235, 'type': 'quiz'}, {'score': 66.28344683278382, 'type': 'homework'}]
# [{'score': 71.64343899778332, 'type': 'exam'}, {'score': 24.80221293650313, 'type': 'quiz'}, {'score': 42.26147058804812, 'type': 'homework'}]
# [{'score': 78.68385091304332, 'type': 'exam'}, {'score': 90.2963101368042, 'type': 'quiz'}, {'score': 34.41620148042529, 'type': 'homework'}]
# [{'score': 44.87186330181261, 'type': 'exam'}, {'score': 25.72395114668016, 'type': 'quiz'}, {'score': 63.42288310628662, 'type': 'homework'}]
# ...

# %%
L =[]
for x in records.find({},{"_id":0, "scores":1}):
  L.append(x["scores"][0]["score"])
print(len(L))
for i in range(len(L)):
  print(L[i])
# Out:
# 200
# 1.463179736705023
# 60.06045071030959
# 67.03077096065002
# 71.64343899778332
# 78.68385091304332
# 44.87186330181261
# 37.32285459166097
# 90.37826509157176
# 22.13583712862635
# 97.00509953654694
# 45.61876862259409
# 78.42617835651868
# 54.29841278520669
# 90.47179954427436
# 25.15924151998215
# 69.1565022533158
# 7.772386442858281
# 39.41011069729274
# 62.12870233109035
# 44.51211101958831
# 42.17439799514388
# 46.2289476258328
# 75.04996547553947
# 45.65432764125526
# 86.0319702155683
# 74.75289335591543
# 19.17861192576963
# 8.606983261043888
# 3.677565278992456
# 48.36644963899371
# 15.89771199662455
# 24.90138146001744
# 87.14345376886205
# 73.15861249943812
# 7.112266875518214
# 27.22049103148209
# 73.055900093666
# 86.06759716616264
# 34.64373397163318
# 0.04381116979284005
# 84.53009035375172
# 28.02518041693717
# 44.62441703708117
# 15.29147856258362
# 98.06441387027331
# 42.1011312120801
# 16.89237820123443
# 92.96916908741805
# 35.43490750932609
# ...

# %%
L = []
K = 0
for x in records.find({},{"_id":0, "scores":1}):
  for i in range(200):
    K += x["scores"][i]["score"]
    L.append(K)
    break
#uncertain
# Out:
# 1.463179736705023
# 2.926359473410046
# 4.389539210115069
# 64.44998992042466
# 124.51044063073425
# 184.57089134104385
# 251.60166230169386
# 318.63243326234385
# 385.66320422299384
# 457.3066432207772
# 528.9500822185605
# 600.5935212163438
# 679.2773721293871
# 757.9612230424304
# 836.6450739554738
# 881.5169372572864
# 926.388800559099
# 971.2606638609116
# 1008.5835184525725
# 1045.9063730442335
# 1083.2292276358944
# 1173.6074927274663
# 1263.985757819038
# 1354.36402291061
# 1376.4998600392364
# 1398.6356971678629
# 1420.7715342964893
# 1517.7766338330362
# 1614.781733369583
# 1711.7868329061298
# 1757.405601528724
# 1803.0243701513182
# 1848.6431387739124
# 1927.069317130431
# 2005.4954954869497
# 2083.9216738434684
# 2138.2200866286753
# 2192.518499413882
# 2246.816912199089
# 2337.2887117433634
# 2427.7605112876377
# 2518.232310831912
# 2543.391552351894
# 2568.550793871876
# 2593.710035391858
# 2662.866537645174
# 2732.02303989849
# 2801.179542151806
# 2808.951928594664
# ...

# %%
L =[]
K = 0
G = []
for x in records.find({},{"_id":0, "scores":1}):
  for i in range(3):
    L.append(x["scores"][i]["score"])
  #print(L)
  for i in range(3):
    K += L[i]
  #print(K)
  G.append(K)
  L = []
  K = 0
print(G.index(max(G)))  #maximum total score %%% CORRECT print(G) gives you total sums
# Out:
# 13

# %%
#Finding the name of the student who scored maximum total score : %%%%%%   QUESTION 1 %%%%%%%%
Z1 = []
for x in records.find({},{"_id":0, "name":1}):
  Z1.append(x["name"])
print(Z1[G.index(max(G))])
print(Z1[13])

print("The maximum total score is:---",max(G),"-----The maximum total scorer in all types together:--",Z1[G.index(max(G))])
# Out:
# Jessika Dagenais
# Jessika Dagenais
# The maximum total score is:--- 275.94947751518237 -----The maximum total scorer in all types together:-- Jessika Dagenais

# %%
#average of score in "exam"
L1 =[]
for x in records.find({},{"_id":0, "scores":1}):
  L1.append(x["scores"][0]["score"])
print(len(L1))
avg = sum(L1)/len(L1)
print(avg)
# Out:
# 200
# 48.673670759501775

# %%
#list of students below average less than the average 48%, and above or equal to 40% (40%<=marks<=48%) : %%%%%%%%%%   QUESTION 5   %%%%%%%%%
L2 = []
L3 = []
for i in range(200):
  if(40 <= L1[i] <= int(avg)):
    L2.append(i)
for i in range(len(L2)):
  L3.append(Z1[L2[i]])
print(L3)
# Out:
# ['Wilburn Spiess', 'Denisha Cast', 'Gisela Levin', 'Tressa Schwing', 'Rosana Vales', 'Tamika Schildgen', 'Kayce Kenyon', 'Terica Brugger', 'Chad Rahe', 'Jenise Mcguffie', 'Cassi Heal', 'Demarcus Audette', 'Flora Duell', 'Quincy Danaher', 'Alix Sherrill', 'Laureen Salomone', 'Gwyneth Garling', 'Aleida Elsass', 'Alica Pasley', 'Malisa Jeanes', 'Harriett Velarde', 'Mariela Sherer']

# %%
#list of student less then 40% FAIL ------ Equal or above 40% as PASS  : %%%%%%%% QUESTION 3 %%%%%%%%%%%
IF = [] #index of failues marks
IP = [] #index of pass marks
FAIL = [] #names list of failure
PASS = [] #name list of pass
for i in range(200):
  if(L1[i] >=40):
    IP.append(i)
  elif(L1[i] < 40):
    IF.append(i)
for i in range(len(IP)):
  PASS.append(Z1[IP[i]])
for i in range(len(IF)):
  FAIL.append(Z1[IF[i]])
print("Total no of pass: and Total number of failed and Total students", len(PASS),len(FAIL),len(PASS)+len(FAIL))
print(PASS)
print(FAIL)
# Out:
# Total no of pass: and Total number of failed and Total students 119 81 200
# ...

# %%
#EXAM QUIZ HOMEWORK their individual totals, individual averages   %%%%%%% QUESTION 4 %%%%%%%%
EXAM =[]
QUIZ = []
HOMEWORK = []
for x in records.find({},{"_id":0, "scores":1}):
  EXAM.append(x["scores"][0]["score"])

S1 = sum(EXAM)
avg1 = sum(EXAM)/len(EXAM)
print("EXAM total and average are:--", S1,avg1)

for x in records.find({},{"_id":0, "scores":1}):
  QUIZ.append(x["scores"][1]["score"])

S2 = sum(QUIZ)
avg2 = sum(QUIZ)/len(QUIZ)
print("QUIZ total and average are:--", S2,avg2)

for x in records.find({},{"_id":0, "scores":1}):
  HOMEWORK.append(x["scores"][2]["score"])

S3 = sum(HOMEWORK)
avg3 = sum(HOMEWORK)/len(HOMEWORK)
print("HOMEWORK total and average are:--", S3,avg3)
# Out:
# EXAM total and average are:-- 9734.734151900355 48.673670759501775
# QUIZ total and average are:-- 9799.34463886051 48.99672319430255
# HOMEWORK total and average are:-- 13563.739241322293 67.81869620661146

# %%
#list of students below average less than the average 48%, and above or equal to 40% (40%<=marks<=48%) : %%%%%%%%%%   QUESTION 2   %%%%%%%%%
L21 = []
L31 = []
for i in range(200):
  if(L1[i] <= int(avg)):
    L21.append(i)
for i in range(len(L2)):
  L31.append(Z1[L2[i]])
print(L31)
# Out:
# ['Wilburn Spiess', 'Denisha Cast', 'Gisela Levin', 'Tressa Schwing', 'Rosana Vales', 'Tamika Schildgen', 'Kayce Kenyon', 'Terica Brugger', 'Chad Rahe', 'Jenise Mcguffie', 'Cassi Heal', 'Demarcus Audette', 'Flora Duell', 'Quincy Danaher', 'Alix Sherrill', 'Laureen Salomone', 'Gwyneth Garling', 'Aleida Elsass', 'Alica Pasley', 'Malisa Jeanes', 'Harriett Velarde', 'Mariela Sherer']

# %%
#list of students who failed    %%%%%%%%% QUESTION 6 : ALSO THE FAIL PART IN QUESTION 3 %%%%%%%%%%%%%%%%%%%
IF = [] #index of failues marks
FAIL = [] #names list of failure
for i in range(200):
  if(L1[i] < 40):
    IF.append(i)

for i in range(len(IF)):
  FAIL.append(Z1[IF[i]])
print("Total number of failed ", len(FAIL))
print(FAIL)
# Out:
# Total number of failed  81
# ...

# %%
#list of students who failed    %%%%%%%%% QUESTION 7 : ALSO THE PASS PART IN QUESTION 3 %%%%%%%%%%%%%%%%%%%
IP = [] #index of pass marks
PASS = [] #name list of pass
for i in range(200):
  if(L1[i] >=40):
    IP.append(i)
  
for i in range(len(IP)):
  PASS.append(Z1[IP[i]])

print("Total no of pass", len(PASS))
print(PASS)
# Out:
# Total no of pass 119
# ...
